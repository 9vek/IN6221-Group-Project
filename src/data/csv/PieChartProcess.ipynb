# %%
import pandas as pd

# %%
df = pd.read_csv("RecyclingRateByWasteType.csv")

# %%
df
# Out:
#      year           waste_type  recycling_rate
# 0    2000  Construction Debris              61
# 1    2000            Used Slag              45
# 2    2000        Ferrous Metal              92
# 3    2000          Scrap Tyres              54
# 4    2000    Non-Ferrous Metal              84
# ..    ...                  ...             ...
# 219  2015                Glass              19
# 220  2015                 Food              13
# 221  2015             Textiles               8
# 222  2015       Ash and Sludge              13
# 223  2015               Others               2
#
# [224 rows x 3 columns]

# %%
grouped_df = df.groupby("year")
for year, group in grouped_df:
    group.drop("year", axis=1, inplace=True)
    print(year)
    display(group)
    group.to_csv(f"./RecyclingRateByWasteType/{year}.csv", index=False)
# Out:
# 2000
#              waste_type  recycling_rate
# 0   Construction Debris              61
# 1             Used Slag              45
# 2         Ferrous Metal              92
# 3           Scrap Tyres              54
# 4     Non-Ferrous Metal              84
# 5                  Wood               9
# 6       Paper/Cardboard              43
# 7   Horticultural Waste              42
# 8              Plastics              21
# 9                 Glass              14
# 10                 Food               1
# 11             Textiles               0
# 12       Ash and Sludge               0
# 13               Others               1
# 2001
#              waste_type  recycling_rate
# 14  Construction Debris              85
# 15            Used Slag              90
# 16        Ferrous Metal              87
# 17          Scrap Tyres              59
# 18    Non-Ferrous Metal              85
# 19                 Wood               8
# 20      Paper/Cardboard              36
# ...
